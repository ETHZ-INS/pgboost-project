# %% [markdown]
# # Setup | Version |  Package Imports

# %%
import os
import snapatac2 as snap
import anndata
import pandas as pd
import numpy as np
import scanpy as sc
import sys
import glob, os, re
from pathlib import Path
import resource

# %% [markdown]
# ### Softcap | Hardcap | Memory Increase

# %%
soft, hard = resource.getrlimit(resource.RLIMIT_AS)
print(f"Before: soft = {soft//1024//1024} MiB, hard = {'unlimited' if hard == resource.RLIM_INFINITY else hard//1024//1024} MiB")

resource.setrlimit(resource.RLIMIT_AS, (hard, hard))

soft_after, hard_after = resource.getrlimit(resource.RLIMIT_AS)
print(f"After:  soft = {soft_after//1024//1024} MiB, hard = {'unlimited' if hard_after == resource.RLIM_INFINITY else hard_after//1024//1024} MiB")
# Out:
# Before: soft = 146484 MiB, hard = 292968 MiB
# After:  soft = 292968 MiB, hard = 292968 MiB

# %% [markdown]
# ### Garbace Collecting

# %%
import gc
gc.collect()
# Out:
# 20

# %% [markdown]
# ### Project Root

# %%
PROJECT_ROOT = Path.cwd().parent    
DATA_DIR     = PROJECT_ROOT / "data"
RAW_DIR      = DATA_DIR / "raw_data"
OUTPUT_DIR   = PROJECT_ROOT / "output"
print("Working directory is now:", PROJECT_ROOT)
# Out:
# Working directory is now: /mnt/germain/work/tomohl/pgboost-project

# %% [markdown]
# # Fragment / Object Imports

# %% [markdown]
# ## Cohort Definitions

# %%
import os
import glob

frag_paths = {}

# 1. Iterate through all subdirectories in the root_dir
for subdir in glob.glob(os.path.join(RAW_DIR, "*")):
    # 2. Check if the current item is a directory
    if os.path.isdir(subdir):
        # 3. Search for the fragment file within each subdirectory
        pattern = os.path.join(subdir, "*_atac_fragments.tsv.gz")
        frag_file = glob.glob(pattern)
        
        # 4. If a fragment file is found, add it to the dictionary
        if frag_file:
            # The key is the directory name (e.g., "GSM5818649")
            key = os.path.basename(subdir)
            frag_paths[key] = frag_file[0]

# Now, `frag_paths` will contain the full paths to the fragment files
# with the directory name as the key.

# %%
files = [(s, frag) for s, frag in frag_paths.items()]

# %% [markdown]
# ## Fragment Import

# %%
# %%time
 
out_dir = DATA_DIR / "fragment_files" / "fragments-1"
out_dir.mkdir(parents=True, exist_ok=True)

out_paths = [
    out_dir / f"{name}.h5ad"
    for name, _ in files
]


adatas = snap.pp.import_fragments(
    [fl for _, fl in files],
    file=[str(p) for p in out_paths],
    chrom_sizes=snap.genome.hg38,
    min_num_fragments=500,
    sorted_by_barcode = False,
    n_jobs = 12
)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34/34 [08:31<00:00, 15.04s/it]
# CPU times: user 206 ms, sys: 86.9 ms, total: 293 ms
# Wall time: 8min 33s

# %%
adatas
# Out:
# [AnnData object with n_obs x n_vars = 2709 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818676.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3924 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818654.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3442 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818674.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3030 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818657.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2425 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818649.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2085 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818655.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3660 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818665.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2205 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818659.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3443 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818677.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 4389 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818678.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2128 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818679.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 23108 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818670.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3135 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818662.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2453 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818658.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2054 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818671.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2821 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818653.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3141 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818668.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2924 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818660.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1803 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818650.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2576 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818666.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2644 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818673.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3692 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818661.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2169 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818667.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2350 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818664.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3659 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818651.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3635 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818663.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1936 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818672.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3466 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818681.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3195 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818675.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1894 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818669.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2367 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818656.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2821 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818652.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2101 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818680.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3581 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818682.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito'
#      uns: 'reference_sequences'
#      obsm: 'fragment_paired']

# %% [markdown]
# # Load Imported Fragments

# %%
out_dir = PROJECT_ROOT / "data" / "fragment_files" / "fragments-1"
out_dir.mkdir(parents=True, exist_ok=True)

out_paths = [
    out_dir / f"{name}.h5ad"
    for name, _ in files
]

adatas = [snap.read(str(p)) for p in out_paths]

# %% [markdown]
# # Metrics

# %%
# %%time
snap.metrics.tsse(adatas, snap.genome.hg38)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34/34 [00:43<00:00,  1.28s/it]
# CPU times: user 192 ms, sys: 32.6 ms, total: 225 ms
# Wall time: 44 s

# %% [markdown]
# ## TSSE Test Plot

# %%
adata_map = {
    name: adata
    for (name, _), adata in zip(files, adatas)
}

adata_map
# Out:
# {'GSM5818676': AnnData object with n_obs x n_vars = 2264 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818676.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'frac_overlap_TSS', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818654': AnnData object with n_obs x n_vars = 2894 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818654.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'library_tsse', 'reference_sequences', 'TSS_profile'
#      obsm: 'fragment_paired',
#  'GSM5818674': AnnData object with n_obs x n_vars = 3173 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818674.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'reference_sequences', 'library_tsse', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818657': AnnData object with n_obs x n_vars = 2830 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818657.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'frac_overlap_TSS', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818649': AnnData object with n_obs x n_vars = 2207 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818649.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'reference_sequences', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818655': AnnData object with n_obs x n_vars = 1940 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818655.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'TSS_profile', 'frac_overlap_TSS', 'library_tsse'
#      obsm: 'fragment_paired',
#  'GSM5818665': AnnData object with n_obs x n_vars = 3118 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818665.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'frac_overlap_TSS', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818659': AnnData object with n_obs x n_vars = 2017 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818659.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'library_tsse', 'frac_overlap_TSS', 'reference_sequences', 'TSS_profile'
#      obsm: 'fragment_paired',
#  'GSM5818677': AnnData object with n_obs x n_vars = 3134 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818677.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences', 'library_tsse'
#      obsm: 'fragment_paired',
#  'GSM5818678': AnnData object with n_obs x n_vars = 4154 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818678.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'TSS_profile', 'frac_overlap_TSS', 'library_tsse'
#      obsm: 'fragment_paired',
#  'GSM5818679': AnnData object with n_obs x n_vars = 1934 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818679.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818670': AnnData object with n_obs x n_vars = 3281 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818670.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'library_tsse', 'reference_sequences', 'TSS_profile', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818662': AnnData object with n_obs x n_vars = 2933 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818662.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'library_tsse', 'TSS_profile', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818658': AnnData object with n_obs x n_vars = 2101 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818658.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'reference_sequences', 'TSS_profile', 'library_tsse'
#      obsm: 'fragment_paired',
#  'GSM5818671': AnnData object with n_obs x n_vars = 1751 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818671.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'library_tsse', 'reference_sequences', 'frac_overlap_TSS', 'TSS_profile'
#      obsm: 'fragment_paired',
#  'GSM5818653': AnnData object with n_obs x n_vars = 927 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818653.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'TSS_profile', 'library_tsse', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818668': AnnData object with n_obs x n_vars = 2895 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818668.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'TSS_profile', 'library_tsse', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818660': AnnData object with n_obs x n_vars = 2695 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818660.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'library_tsse', 'TSS_profile', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818650': AnnData object with n_obs x n_vars = 1594 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818650.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences', 'library_tsse'
#      obsm: 'fragment_paired',
#  'GSM5818666': AnnData object with n_obs x n_vars = 1849 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818666.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'frac_overlap_TSS', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818673': AnnData object with n_obs x n_vars = 2473 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818673.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'TSS_profile', 'library_tsse', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818661': AnnData object with n_obs x n_vars = 3305 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818661.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'reference_sequences', 'TSS_profile', 'library_tsse'
#      obsm: 'fragment_paired',
#  'GSM5818667': AnnData object with n_obs x n_vars = 1967 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818667.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'frac_overlap_TSS', 'library_tsse', 'TSS_profile'
#      obsm: 'fragment_paired',
#  'GSM5818664': AnnData object with n_obs x n_vars = 1854 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818664.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'library_tsse', 'TSS_profile', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818651': AnnData object with n_obs x n_vars = 3364 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818651.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'reference_sequences', 'TSS_profile', 'library_tsse'
#      obsm: 'fragment_paired',
#  'GSM5818663': AnnData object with n_obs x n_vars = 3329 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818663.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'library_tsse', 'TSS_profile', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818672': AnnData object with n_obs x n_vars = 1697 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818672.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'library_tsse', 'frac_overlap_TSS', 'TSS_profile'
#      obsm: 'fragment_paired',
#  'GSM5818681': AnnData object with n_obs x n_vars = 3250 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818681.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'frac_overlap_TSS', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818675': AnnData object with n_obs x n_vars = 2954 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818675.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'reference_sequences', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818669': AnnData object with n_obs x n_vars = 1446 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818669.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'reference_sequences', 'library_tsse', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  'GSM5818656': AnnData object with n_obs x n_vars = 1826 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818656.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818652': AnnData object with n_obs x n_vars = 2598 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818652.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'frac_overlap_TSS', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818680': AnnData object with n_obs x n_vars = 1977 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818680.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'frac_overlap_TSS', 'reference_sequences'
#      obsm: 'fragment_paired',
#  'GSM5818682': AnnData object with n_obs x n_vars = 3383 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818682.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'library_tsse', 'TSS_profile', 'reference_sequences', 'frac_overlap_TSS'
#      obsm: 'fragment_paired'}

# %%
import plotly, plotly.io as pio
import matplotlib.pyplot as plt


print("plotly:", plotly.__version__)
print("current renderer:", pio.renderers.default)

# 1) Force a Jupyter-friendly renderer
# Try these in order
for r in ["notebook_connected", "notebook", "jupyterlab", "vscode", "browser"]:
    try:
        pio.renderers.default = r
        # test a tiny plotly fig to confirm it renders
        import plotly.graph_objects as go
        go.Figure(data=[go.Scatter(y=[0,1,0])], layout_title_text=f"Renderer test: {r}")
        break
    except Exception as e:
        continue

print("using renderer:", pio.renderers.default)

# 2) Ask snapatac2 to draw the interactive TSSE plot
_ = snap.pl.tsse(adata_map["GSM5818649"], interactive=True)

# 3) Fallback to Matplotlib if nothing showed (safe in any environment)
try:
    # If we got here and still see nothing, do a static plot:
    snap.pl.tsse(adata_map["GSM5818649"], interactive=False)
    plt.show()
except Exception:
    pass
# Out:
# plotly: 6.2.0
# current renderer: notebook_connected
# using renderer: notebook_connected
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="6f5c49ef-b244-46ac-95b5-b4ed82223fd8" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6f5c49ef-b244-46ac-95b5-b4ed82223fd8")) {                    Plotly.newPlot(                        "6f5c49ef-b244-46ac-95b5-b4ed82223fd8",                        [{"colorbar":{"ticktext":["0.008","0.022","0.041","0.070","0.102","0.139","0.179","0.218","0.258","0.297"],"tickvals":[1,2,3,4,5,6,7,8,9],"title":{"text":"Density"},"y":1,"yanchor":"top"},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"line":{"smoothing":0.85},"x":{"dtype":"f8","bdata":"Y+SXSBG8fkDqDwQOdq2AQCi83\u002fJ8GYJAcrEtk42kg0DAs\u002fdoTVGFQKm+x7GbIodA5Yd7W5YbiUDxdphcnz+LQG+LSoFiko1Avl6A2+0LkECCQbnwLmqRQLfkYiJN5pJAUjbGSNSClEAi3zLQh0KWQPPwHnZnKJhAAdK1bbQ3mkADGaj09nOcQI2LzmEE4Z5Aba0B3ILBoEDIuTtkPy+iQIzhX\u002fgqvKNANq\u002fwQO5qpUA0oWLvaz6nQNt027DFOalA1CPzjGFgq0CeEqy577WtQJd4UHc4H7BAcHkgoR5\u002fsUBy4W\u002fOBf2yQNzDL+d8m7RAdQ8pqkpdtkAGrM5vckW4QFsu+1Q5V7pAK3F21iuWvEDZxeDmIwa\u002fQOiqucSn1cBAnYt0\u002fhtFwkDFdW3B5NPDQI7lcuithMVASoQKnV1ax0CsWSNQGVjJQBCJSx9LgctAOyqqr6fZzUC34WNEmjLQQAqKBX0nlNFArN1ey9kT00CNNLcqQ7TUQBI3T7AteNZAoEPsU6Bi2EDRWswg5HbaQMOF6deJuNxAYvo1DXAr30AIkSbl5OngQAJB\u002feASW+JAbPJ3ELvr40DC14iEjJ7lQHxq8uJwdudANKrzZJF26UDaW\u002fpCXKLrQOz5ppaK\u002fe1A+HWcXhNG8ECQ56qiSanxQPDJBjrJKvNA4UUANyfN9EAQ\u002flIJMZP2QKaecUzxf\u002fhAoHi3\u002frSW+kAE0XEqEdv8QFPEdQrpUP9A+r5lWjr+AEFnuG4rJHECQWzkyQeuAwRB245pOoq4BUFwqn3ppZIHQe9MIRsulQlBDj2RJ5XDC0HEb0KimCEOQW6W\u002feGjWRBB+mZ3MIW+EUGMEWY71EETQfyN2S8p5hRBzIwQ3FSuFkHXGouDZZ0YQSFtgRysthpBqzy7\u002f8H9HEHuP4gUj3YfQb2Ut0GoEiFByMyH\u002fU+HIkEMEtfJvRskQTXReC+n0iVB3ihA2fyuJ0Gv2rWe77MpQaT92vz15CtBuIlaBtJFLkG2UazqS20wQQRq9kTa0zFBhMqi8PpYM0Ezrzw5Sf80QQjDkk+ZyTZBgMmXI\u002f26OEE="},"y":{"dtype":"f8","bdata":"BnLJKbgICkAWXOi\u002fH3ULQCZGB1aH4QxANjAm7O5NDkBGGkWCVroPQCsCMgxfkxBAM3dB15JJEUA77FCixv8RQENhYG36tRJAS9ZvOC5sE0BTS38DYiIUQFvAjs6V2BRAYzWemcmOFUBrqq1k\u002fUQWQHMfvS8x+xZAe5TM+mSxF0CDCdzFmGcYQIt+65DMHRlAk\...\u002fcK0D2zcm7WTcsQHqIUaFzkixA\u002fkLZho3tLECC\u002fWBsp0gtQAa46FHBoy1AinJwN9v+LUAOLfgc9VkuQJLnfwIPtS5AFqIH6CgQL0CaXI\u002fNQmsvQB4XF7Ncxi9A0WhPTLsQMEATRhM\u002fSD4wQFUj1zHVazBAlwCbJGKZMEDZ3V4X78YwQBu7Igp89DBAXZjm\u002fAgiMUCfdarvlU8xQOFSbuIifTFAIzAy1a+qMUBlDfbHPNgxQKfqubrJBTJA6cd9rVYzMkArpUGg42AyQG2CBZNwjjJAr1\u002fJhf27MkDxPI14iukyQDMaUWsXFzNAdfcUXqREM0C31NhQMXIzQPmxnEO+nzNAO49gNkvNM0B9bCQp2PozQL9J6BtlKDRAASesDvJVNEBDBHABf4M0QIXhM\u002fQLsTRAx7735pjeNEA="},"z":{"dtype":"f8","bdata":"mpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZ ...

# %%
snap.pp.filter_cells(adatas, min_tsse=5.0)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34/34 [01:09<00:00,  2.05s/it]

# %% [markdown]
# # Create AnnDataSet Object

# %%
adatas
# Out:
# [AnnData object with n_obs x n_vars = 2264 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818676.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'library_tsse', 'TSS_profile', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2894 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818654.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3173 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818674.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'reference_sequences', 'library_tsse'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2830 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818657.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'library_tsse', 'reference_sequences', 'TSS_profile'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2207 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818649.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'library_tsse', 'TSS_profile', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1940 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818655.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'frac_overlap_TSS', 'library_tsse', 'TSS_profile'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3118 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818665.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'reference_sequences', 'frac_overlap_TSS', 'library_tsse'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2017 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818659.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'library_tsse', 'reference_sequences', 'TSS_profile', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3134 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818677.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 4154 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818678.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'frac_overlap_TSS', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1934 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818679.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'reference_sequences', 'library_tsse', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3281 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818670.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'reference_sequences', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2933 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818662.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'reference_sequences', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2101 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818658.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1751 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818671.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 927 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818653.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'reference_sequences', 'library_tsse', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2895 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818668.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'frac_overlap_TSS', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2695 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818660.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1594 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818650.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'frac_overlap_TSS', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1849 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818666.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'library_tsse', 'frac_overlap_TSS', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2473 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818673.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'frac_overlap_TSS', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3305 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818661.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'TSS_profile', 'frac_overlap_TSS', 'library_tsse'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1967 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818667.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'library_tsse', 'reference_sequences', 'TSS_profile'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1854 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818664.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'library_tsse', 'TSS_profile', 'reference_sequences', 'frac_overlap_TSS'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3364 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818651.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences', 'library_tsse'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3329 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818663.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'reference_sequences', 'library_tsse'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1697 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818672.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'frac_overlap_TSS', 'TSS_profile', 'library_tsse', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3250 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818681.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'TSS_profile', 'frac_overlap_TSS', 'library_tsse'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2954 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818675.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'library_tsse', 'frac_overlap_TSS', 'TSS_profile', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1446 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818669.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'TSS_profile', 'frac_overlap_TSS', 'library_tsse'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1826 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818656.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'library_tsse', 'frac_overlap_TSS', 'TSS_profile', 'reference_sequences'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 2598 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818652.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'TSS_profile', 'reference_sequences', 'frac_overlap_TSS', 'library_tsse'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 1977 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818680.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'reference_sequences', 'frac_overlap_TSS', 'TSS_profile', 'library_tsse'
#      obsm: 'fragment_paired',
#  AnnData object with n_obs x n_vars = 3383 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/fragment_files/fragments-1/GSM5818682.h5ad'
#      obs: 'n_fragment', 'frac_dup', 'frac_mito', 'tsse'
#      uns: 'library_tsse', 'TSS_profile', 'frac_overlap_TSS', 'reference_sequences'
#      obsm: 'fragment_paired']

# %%
# %%time
out = DATA_DIR / "AnnDataSet-1.h5ads"

data = snap.AnnDataSet(
    adatas=[(name, adata) for (name, _), adata in zip(files, adatas)],
    filename= out
)
data
# Out:
# CPU times: user 114 ms, sys: 47.5 ms, total: 161 ms
# Wall time: 132 ms
# AnnDataSet object with n_obs x n_vars = 85114 x 0 backed at '/mnt/germain/work/tomohl/pgboost-project/data/AnnDataSet-1.h5ads'
# contains 34 AnnData objects with keys: 'GSM5818676', 'GSM5818654', 'GSM5818674', 'GSM5818657', 'GSM5818649', 'GSM5818655', 'GSM5818665', 'GSM5818659', 'GSM5818677', 'GSM5818678', 'GSM5818679', 'GSM5818670', 'GSM5818662', 'GSM5818658', 'GSM5818671', 'GSM5818653', 'GSM5818668', 'GSM5818660', 'GSM5818650', 'GSM5818666', 'GSM5818673', 'GSM5818661', 'GSM5818667', 'GSM5818664', 'GSM5818651', 'GSM5818663', 'GSM5818672', 'GSM5818681', 'GSM5818675', 'GSM5818669', 'GSM5818656', 'GSM5818652', 'GSM5818680', 'GSM5818682'
#     obs: 'sample'
#     uns: 'reference_sequences', 'AnnDataSet'

# %%
snap.read_dataset("AnnDataSet-1.h5ads", adata_files_update=None, mode='r+', backend=None)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 snap.read_dataset("AnnDataSet-1.h5ads", adata_files_update=None, mode='r+', backend=None)
#
# RuntimeError: H5Fopen(): unable to open file: unable to open file: name = 'AnnDataSet-1.h5ads', errno = 2, error message = 'No such file or directory', flags = 1, o_flags = 2

# %% [markdown]
# # Create Peak Matrix

# %%
peak_fp     = DATA_DIR / "peak_matrices" / "PeakMatrix-1.h5ads"
peak_adata = snap.read(filename=str(peak_fp), backed = 'r+', backend = None)

# %%
peak_adata
# Out:
# AnnData object with n_obs x n_vars = 87346 x 230203 backed at '/mnt/germain/work/tomohl/pgboost-project/data/peak_matrices/25-08-13_peakmatrix_human.h5ads'
#     obs: 'sample', 'dataset'
#     var: 'count', 'selected'
#     uns: 'spectral_eigenvalue'
#     obsm: 'X_spectral'

# %%
out_peak = DATA_DIR / "peak_matrices" / "PeakMatrix-1.h5ads"
peak_file = DATA_DIR / "consensus_peaks.bed"
out_peak.parent.mkdir(exist_ok=True, parents=True)

frag_ds = data

peak_adata = snap.pp.make_peak_matrix(
    frag_ds,
    peak_file      = peak_file,
    use_rep        = None,
    max_frag_size  = 2000,
    inplace        = False,  
    file           = str(out_peak)
)

print(peak_adata)
# Out:
# AnnData object with n_obs x n_vars = 85114 x 230203 backed at '/mnt/germain/work/tomohl/pgboost-project/data/peak_matrices/PeakMatrix-1.h5ads'
#     obs: 'sample'

# %% [markdown]
# ## Generate Unique Cell ID's

# %%
#Unique cell IDs
unique_cell_ids = [
    f"{sa}:{bc}"
    for sa, bc in zip(peak_adata.obs['sample'], peak_adata.obs_names)
]
peak_adata.obs_names = unique_cell_ids
assert peak_adata.n_obs == np.unique(peak_adata.obs_names).size
# Out:
# /tmp/ipykernel_796998/1341617858.py:4: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'

# %% [markdown]
# # Select Features

# %%
snap.pp.select_features(peak_adata, n_features=200000, inplace=True)


print(f'Number of cells: {peak_adata.n_obs}')
print(f'Number of unique barcodes: {np.unique(peak_adata.obs_names).size}')
# Out:
# 2025-09-02 16:26:31 - INFO - Selected 200000 features.
# Number of cells: 85114
# Number of unique barcodes: 85114

# %%
print("peak_adata X shape:", peak_adata.X.shape)      
print("n_obs, n_vars:", peak_adata.n_obs, peak_adata.n_vars)

print("total vars in .X:", peak_adata.n_vars)
print("features flagged:", peak_adata.var['selected'].sum())
# Out:
# peak_adata X shape: [85114, 230203]
# n_obs, n_vars: 85114 230203
# total vars in .X: 230203
# features flagged: 200000
# /tmp/ipykernel_796998/3144355972.py:5: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'

# %% [markdown]
# # Spectral Embedding

# %%
snap.tl.spectral(peak_adata)

# %%
peak_adata
# Out:
# AnnData object with n_obs x n_vars = 85114 x 230203 backed at '/mnt/germain/work/tomohl/pgboost-project/data/peak_matrices/PeakMatrix-1.h5ads'
#     obs: 'sample'
#     var: 'count', 'selected'
#     uns: 'spectral_eigenvalue'
#     obsm: 'X_spectral'

# %% [markdown]
# # Batch Correction

# %% [markdown]
# ## Create Dataset Identifyer

# %%
# Extract the part before "_" for each sample name
peak_adata.obs["dataset"] = [name.split("_", 1)[0] for name in peak_adata.obs["sample"]]


print(set(peak_adata.obs["dataset"]))
# Out:
# /tmp/ipykernel_796998/976835505.py:2: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'
# {'GSM5818668', 'GSM5818651', 'GSM5818650', 'GSM5818661', 'GSM5818667', 'GSM5818671', 'GSM5818675', 'GSM5818649', 'GSM5818657', 'GSM5818670', 'GSM5818666', 'GSM5818665', 'GSM5818656', 'GSM5818658', 'GSM5818662', 'GSM5818669', 'GSM5818678', 'GSM5818672', 'GSM5818655', 'GSM5818679', 'GSM5818659', 'GSM5818653', 'GSM5818673', 'GSM5818676', 'GSM5818674', 'GSM5818682', 'GSM5818654', 'GSM5818664', 'GSM5818681', 'GSM5818652', 'GSM5818680', 'GSM5818677', 'GSM5818663', 'GSM5818660'}
# /tmp/ipykernel_796998/976835505.py:5: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'

# %% [markdown]
# ## Harmony

# %%
import sys
print(sys.executable)
# Out:
# /home/tomohl/.conda/envs/snapatac2_env/bin/python

# %%
import pandas as pd
from harmonypy import run_harmony


if "X_spectral_harmony" in peak_adata.obsm:
    del peak_adata.obsm["X_spectral_harmony"]

X_spectral = peak_adata.obsm["X_spectral"]  

meta = pd.DataFrame({
    "sample":  peak_adata.obs["sample"].to_numpy().tolist(),
    "dataset": peak_adata.obs["dataset"].to_numpy().tolist()
})


ho = run_harmony(
    X_spectral,
    meta,
    vars_use=["sample", "dataset"],   
    theta=[3, 4],                     
    lamb=[0.8, 0.5],                  
    plot_convergence=True,            
    max_iter_harmony=20,              
    max_iter_kmeans=300,              
    random_state=0                    
)


corrected = ho.Z_corr.T               
peak_adata.obsm["X_spectral_harmony"] = corrected


print("Original spectral:", X_spectral.shape)
print("Harmony-corrected:", corrected.shape)
# Out:
# /tmp/ipykernel_796998/223992479.py:12: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'
#
# /tmp/ipykernel_796998/223992479.py:13: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'
#
# 2025-09-02 17:01:36,740 - harmonypy - INFO - Computing initial centroids with sklearn.KMeans...
# 2025-09-02 17:01:36 - INFO - Computing initial centroids with sklearn.KMeans...
# 2025-09-02 17:01:40,569 - harmonypy - INFO - sklearn.KMeans initialization complete.
# 2025-09-02 17:01:40 - INFO - sklearn.KMeans initialization complete.
# 2025-09-02 17:01:40,868 - harmonypy - INFO - Iteration 1 of 20
# 2025-09-02 17:01:40 - INFO - Iteration 1 of 20
# 2025-09-02 17:02:09,912 - harmonypy - INFO - Iteration 2 of 20
# 2025-09-02 17:02:09 - INFO - Iteration 2 of 20
# 2025-09-02 17:02:37,512 - harmonypy - INFO - Iteration 3 of 20
# 2025-09-02 17:02:37 - INFO - Iteration 3 of 20
# 2025-09-02 17:02:47,246 - harmonypy - INFO - Converged after 3 iterations
# 2025-09-02 17:02:47 - INFO - Converged after 3 iterations
# Original spectral: (85114, 30)
# Harmony-corrected: (85114, 30)

# %%
peak_adata.obsm["X_spectral_harmony"]
# Out:
# array([[ 3.71435487e-03, -7.73335421e-04, -4.11360466e-04, ...,
#         -1.19565475e-04,  4.01968107e-05, -1.39734736e-05],
#        [ 3.40619781e-03, -5.76135774e-04, -2.15112435e-04, ...,
#         -4.30013060e-05,  1.30288929e-04, -3.35177750e-05],
#        [ 3.82608467e-03, -6.33302896e-04, -9.22011445e-05, ...,
#         -1.18288647e-05, -2.05390646e-05,  1.21695053e-06],
#        ...,
#        [ 3.68682149e-03, -4.98666236e-04, -1.92009066e-04, ...,
#          2.29589864e-04, -2.10888872e-05,  4.65896695e-05],
#        [ 3.47792240e-03, -3.20135401e-04, -1.13258429e-04, ...,
#          1.20062370e-04,  1.18879892e-04,  1.18381646e-05],
#        [ 2.02819738e-03,  1.99145748e-03, -7.92397212e-04, ...,
#          3.33456762e-05, -1.45094422e-04,  1.05267745e-04]])

# %%
emb_unc = peak_adata.obsm["X_spectral"]
df_unc = pd.DataFrame(
    emb_unc,
    index   = peak_adata.obs_names,
    columns = [f"Spectral{i+1}" for i in range(emb_unc.shape[1])]
)
# add metadata
df_unc["sample"] = peak_adata.obs["sample"].to_numpy()
df_unc["dataset"] = peak_adata.obs["dataset"].to_numpy()

out_unc = DATA_DIR / "Spectral_embedding_uncorrected-1.csv"
df_unc.to_csv(out_unc)
print(f"Wrote {df_unc.shape[0]} cells × {df_unc.shape[1]} columns to {out_unc}")

emb_harm = peak_adata.obsm["X_spectral_harmony"]
df_harm = pd.DataFrame(
    emb_harm,
    index   = peak_adata.obs_names,
    columns = [f"Spectral{i+1}" for i in range(emb_harm.shape[1])]
)
# add metadata
df_harm["sample"]  = peak_adata.obs["sample"].to_numpy()
df_harm["dataset"] = peak_adata.obs["dataset"].to_numpy()

out_harm = DATA_DIR / "Spectral_embedding_harmony-1.csv"
df_harm.to_csv(out_harm)
print(f"Wrote {df_harm.shape[0]} cells × {df_harm.shape[1]} columns to {out_harm}")
# Out:
# /tmp/ipykernel_796998/2431607695.py:8: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'
#
# /tmp/ipykernel_796998/2431607695.py:9: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'
# Wrote 85114 cells × 32 columns to /mnt/germain/work/tomohl/pgboost-project/data/Spectral_embedding_uncorrected-1.csv
# /tmp/ipykernel_796998/2431607695.py:22: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'
#
# /tmp/ipykernel_796998/2431607695.py:23: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'
# Wrote 85114 cells × 32 columns to /mnt/germain/work/tomohl/pgboost-project/data/Spectral_embedding_harmony-1.csv

# %%
snap.pp.knn(peak_adata, n_neighbors=50, use_dims=None, use_rep='X_spectral', method='kdtree', inplace=True, random_state=0)

# %%
snap.tl.leiden(peak_adata, resolution=550)

# %%
import polars as pl

# Get the 'leiden' column as a Polars Series
leiden_series = peak_adata.obs["leiden"]

# Count how many times each cluster label appears
cluster_counts = leiden_series.value_counts().sort("leiden")

counts_df = cluster_counts.to_pandas()
# Compute the average number of cells per cluster
average_cells = cluster_counts["count"].mean()

print(cluster_counts)
print(f"\nAverage number of cells per cluster: {average_cells:.1f}")
# Out:
# shape: (5_228, 2)
# ┌────────┬───────┐
# │ leiden ┆ count │
# │ ---    ┆ ---   │
# │ cat    ┆ u32   │
# ╞════════╪═══════╡
# │ 1322   ┆ 20    │
# │ 175    ┆ 36    │
# │ 270    ┆ 33    │
# │ 1816   ┆ 17    │
# │ 3724   ┆ 9     │
# │ …      ┆ …     │
# │ 4911   ┆ 6     │
# │ 5225   ┆ 5     │
# │ 3723   ┆ 10    │
# │ 3440   ┆ 11    │
# │ 5226   ┆ 5     │
# └────────┴───────┘
#
# Average number of cells per cluster: 16.3
# /tmp/ipykernel_796998/740323433.py:4: DeprecationWarning:
#
# `_import_from_c` is deprecated; use `_import_arrow_from_c` instead. If you are using an extension, please compile it with the latest 'pyo3-polars'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.histplot(counts_df["count"], bins=100, kde=False)

plt.xlabel("Cells per cluster")
plt.ylabel("Number of clusters")
plt.title("Cluster size distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Closing Objects

# %%
peak_adata.close()
